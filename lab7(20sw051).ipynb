# %% [markdown]
# <a href="https://colab.research.google.com/github/Godhawari-khatri/Data-science-lab-task/blob/main/lab7(20sw051).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
daimond=pd.read_csv('/content/Diamonds Prices2022.csv')
daimond.head(6)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48

# %%
plt.scatter(data=daimond, x='depth',y='x')
plt.xlabel('Displacement')
plt.ylabel('Combined daimond Efficiency')
# Out:
# Text(0, 0.5, 'Combined daimond Efficiency')

# %%
sns.regplot(data=daimond, x='depth',y='x')
plt.xlabel('Displacement')
plt.ylabel('Combined daimond Efficiency')
# Out:
# Text(0, 0.5, 'Combined daimond Efficiency')

# %%
sns.regplot(data=daimond, x='table',y='depth')
# Out:
# <Axes: xlabel='table', ylabel='depth'>

# %%
sns.regplot(data=daimond, x='table',y='depth',x_jitter=0.3)
# Out:
# <Axes: xlabel='table', ylabel='depth'>

# %%
sns.regplot(data=daimond, x='table',y='depth',x_jitter=0.3,
            scatter_kws={'alpha': 1/20});

# %%
plt.hist2d(data=daimond, x='table',y='depth')
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined daimond Efficiency')
# Out:
# Text(0, 0.5, 'Combined daimond Efficiency')

# %%
plt.hist2d(data=daimond, x='table',y='depth',cmin=0.5);
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined daimond Efficiency')
# Out:
# Text(0, 0.5, 'Combined daimond Efficiency')

# %%
plt.hist2d(data=daimond, x='table',y='depth',cmin=0.5,cmap='viridis_r');
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined daimond Efficiency')
# Out:
# Text(0, 0.5, 'Combined daimond Efficiency')

# %%
base_color = sns.color_palette()[0]
sns.boxplot(data=daimond, x='cut', y='table',color=base_color)
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Ideal'),
#   Text(1, 0, 'Premium'),
#   Text(2, 0, 'Good'),
#   Text(3, 0, 'Very Good'),
#   Text(4, 0, 'Fair')])

# %%
daimond['color_type'] = daimond['color'].apply(lambda x: x.split()[0])

# %%
daimond['color'].head()
# Out:
# 0    E
# 1    E
# 2    E
# 3    I
# 4    J
# Name: color, dtype: object

# %%
ct_counts = daimond.groupby(['cut','color_type']).size()
ct_counts = ct_counts.reset_index(name='count')
ct_counts.pivot(index='cut',columns='color_type',values='count')
# Out:
# color_type     D     E     F     G     H     I    J
# cut
# Fair         163   224   312   314   303   175  119
# Good         662   933   909   871   702   522  307
# Ideal       2834  3903  3826  4884  3115  2093  896
# Premium     1603  2338  2332  2924  2360  1428  808
# Very Good   1513  2401  2164  2299  1824  1204  678

# %%
sns.countplot(data=daimond,x='cut',hue='color_type')
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Ideal'),
#   Text(1, 0, 'Premium'),
#   Text(2, 0, 'Good'),
#   Text(3, 0, 'Very Good'),
#   Text(4, 0, 'Fair')])

# %%
bins = np.arange(12,58+2,2)
g = sns.FacetGrid(data=daimond,col='cut',col_wrap=3)
g.map(plt.hist,'table',bins=bins);

# %%
base_color = sns.color_palette()[7]
sns.barplot(data=daimond,x='cut',y='table',color=base_color)
plt.xticks(rotation=15)
plt.ylabel('Average daimond Efficiency')
# Out:
# Text(0, 0.5, 'Average daimond Efficiency')

# %%
sns.pointplot(data = daimond, x = 'cut', y = 'table')
plt.ylabel('Average daimond Efficiency')
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Ideal'),
#   Text(1, 0, 'Premium'),
#   Text(2, 0, 'Good'),
#   Text(3, 0, 'Very Good'),
#   Text(4, 0, 'Fair')])
